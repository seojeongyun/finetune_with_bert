# %% [markdown]
# <a href="https://colab.research.google.com/github/seojeongyun/finetune_with_bert/blob/main/finetune_with_bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "torch>=2.0" --extra-index-url https://download.pytorch.org/whl/cu117 --upgrade --quiet

# %%
# !pip install "transformers==4.30.1" "datasets==2.9.0" "accelerate==0.20.1" "evaluate==0.4.0" tensorboard scikit-learn --upgrade --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.12 requires torch<2.1,>=1.7, but you have torch 2.1.0 which is incompatible.
# tensorflow 2.13.0 requires tensorboard<2.14,>=2.13, but you have tensorboard 2.14.1 which is incompatible.

# %%
# !sudo apt-get install git-lfs --yes
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.

# %%
### Data_Loader

from datasets import load_dataset
from transformers import AutoTokenizer

class banking:
    def __init__(self, task, tokenizer):
        self.task = task
        self.tokenizer = tokenizer
        # Dataset id from huggingface.co/dataset
        self.dataset_id = "banking77"
        #
        self.raw_dataset = self.get_dataset()
        #
        self.tokenized_dataset, self.labels, self.num_labels, self.label2id, self.id2label = self.transform_id_label()


    def get_dataset(self):
        raw_dataset = load_dataset(self.dataset_id)
        if self.task == 'train':
            raw_dataset = raw_dataset['train']
        else:
            raw_dataset = raw_dataset['test']
        return raw_dataset

    # Tokenize helper function
    def tokenize(self,batch):
        return self.tokenizer(batch['text'], padding='max_length', truncation=True, return_tensors="pt")

    def transform_id_label(self):
        raw_dataset = self.raw_dataset.rename_column("label", "labels")  # to match Trainer
        tokenized_dataset = raw_dataset.map(self.tokenize, batched=True, remove_columns=["text"])

        labels = tokenized_dataset.features["labels"].names

        num_labels = len(labels)
        label2id, id2label = dict(), dict()
        for i, label in enumerate(labels):
            label2id[label] = str(i)
            id2label[str(i)] = label

        return tokenized_dataset, labels, num_labels, label2id, id2label

# %%
### Engine

import evaluate
import numpy as np
import torch

from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from huggingface_hub import HfFolder
from transformers import Trainer, TrainingArguments


class engine:
    def __init__(self):
        self.device = torch.device("cuda:1")
        # Model id to load the tokenizer
        self.model_id = "bert-base-uncased"
        # Load Tokenizer
        self.tokenizer = self.get_tokenizer()
        #
        self.train_dataload = self.get_loader('train', self.tokenizer)
        self.test_dataload = self.get_loader('test', self.tokenizer)
        #
        self.model = self.get_model()
        #
        self.metric = evaluate.load("f1")
        #
        self.repo_id, self.train_args, self.trainer = self.get_args()

    def get_tokenizer(self):
        tokenizer = AutoTokenizer.from_pretrained(self.model_id)
        return tokenizer

    def get_loader(self, task, tokenizer):
        if task == 'train':
            loader = banking(task, tokenizer)
        else:
            loader = banking(task, tokenizer)

        return loader

    def get_model(self):
        model = AutoModelForSequenceClassification.from_pretrained(self.model_id,
                                                                   num_labels=self.train_dataload.num_labels,
                                                                   label2id=self.train_dataload.label2id,
                                                                   id2label=self.train_dataload.id2label)
        return model

        # Metric helper method

    def compute_metrics(self, eval_pred):
        predictions, labels = eval_pred
        predictions = np.argmax(predictions, axis=1)
        return self.metric.compute(predictions=predictions, references=labels, average="weighted")

    def get_args(self):
        # Id for remote repository
        repository_id = "bert-base-banking77-pt2-jy"

        # Define training args
        training_args = TrainingArguments(
            output_dir=repository_id,
            per_device_train_batch_size=16,
            per_device_eval_batch_size=8,
            learning_rate=5e-5,
            num_train_epochs=3,
            # PyTorch 2.0 specifics
            fp16=True,  # bfloat16 training
            torch_compile=True,  # optimizations
            optim="adamw_torch_fused",  # improved optimizer
            # logging & evaluation strategies
            logging_dir=f"{repository_id}/logs",
            logging_strategy="steps",
            logging_steps=200,
            evaluation_strategy="epoch",
            save_strategy="epoch",
            save_total_limit=2,
            load_best_model_at_end=True,
            metric_for_best_model="f1",
            # push to hub parameters
            report_to="tensorboard",
            push_to_hub=True,
            hub_strategy="every_save",
            hub_model_id=repository_id,
            hub_token=HfFolder.get_token(),

        )

        # Create a Trainer instance
        trainer = Trainer(
            model=self.model,
            args=training_args,
            train_dataset=self.train_dataload.tokenized_dataset,
            eval_dataset=self.test_dataload.tokenized_dataset,
            compute_metrics=self.compute_metrics,
        )

        return repository_id, training_args, trainer

# %%
# !pip install --quiet --upgrade --pre torch torchaudio --index-url https://download.pytorch.org/whl/nightly/cu121
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 452.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 91.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 MB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 GB 421.1 kB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.12 requires torch<2.1,>=1.7, but you have torch 2.2.0.dev20231009+cu121 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 2.2.0.dev20231009+cu121 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 2.2.0.dev20231009+cu121 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.2.0.dev20231009+cu121 which is incompatible.

# %%
import torch._dynamo
torch._dynamo.config.suppress_errors = True

# %%
### Train

from huggingface_hub import login

if __name__ == '__main__':
    login(
      token="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", # ADD YOUR TOKEN HERE
      add_to_git_credential=True
    )

    # Start training
    Engine = engine()
    Engine.trainer.train()
# Out:
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# /root/.cache/huggingface/modules/datasets_modules/datasets/banking77/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4/banking77.py:59: FutureWarning: Dataset 'banking77' is deprecated and will be deleted. Use 'PolyAI/banking77' instead.
#   warnings.warn(
# WARNING:datasets.builder:Found cached dataset banking77 (/root/.cache/huggingface/datasets/banking77/default/1.1.0/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4)
#   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/banking77/default/1.1.0/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4/cache-7ddd421b53cb0109.arrow
# WARNING:datasets.builder:Found cached dataset banking77 (/root/.cache/huggingface/datasets/banking77/default/1.1.0/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4)
#   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/banking77/default/1.1.0/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4/cache-c3b98d4721feba05.arrow
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The speedups for torchdynamo mostly come wih GPU Ampere or higher and which is not detected here.
# /content/bert-base-banking77-pt2-jy is already a clone of https://huggingface.co/SeoJeongYun/bert-base-banking77-pt2-jy. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/bert-base-banking77-pt2-jy is already a clone of https://huggingface.co/SeoJeongYun/bert-base-banking77-pt2-jy. Make sure you pull the latest changes with `repo.git_pull()`.
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 1533
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:21,498] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 912
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:55,866] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT get_extended_attention_mask /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py line 863
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:56,178] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 200
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:49:57,377] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 561
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:31,016] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 483
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:33,853] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 415
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:36,219] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 274
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:38,046] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 383
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:41,590] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT apply_chunking_to_forward /usr/local/lib/python3.10/dist-packages/transformers/pytorch_utils.py line 165
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:42,314] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT feed_forward_chunk /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 548
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,013] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 448
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,296] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/activations.py line 77
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,413] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 461
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:43,874] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py line 658
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:44,680] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT _convert_to_fp32 /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py line 512
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING]
# [2023-10-10 11:50:44,855] torch._dynamo.convert_frame: [WARNING]
#     <div>
#
#       <progress value='1557' max='1878' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1557/1878 20:03 < 04:08, 1.29 it/s, Epoch 2.49/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.126800</td>
#       <td>0.804414</td>
#       <td>0.843510</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.403300</td>
#       <td>0.369727</td>
#       <td>0.917249</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1878' max='1878' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1878/1878 25:10, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.126800</td>
#       <td>0.804414</td>
#       <td>0.843510</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.403300</td>
#       <td>0.369727</td>
#       <td>0.917249</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.198900</td>
#       <td>0.312246</td>
#       <td>0.925758</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
    # Save processor and create model card
    Engine.tokenizer.save_pretrained(Engine.repo_id)
    Engine.trainer.create_model_card()
    Engine.trainer.push_to_hub()
# Out:
# Upload file logs/events.out.tfevents.1696938526.0478456f1f90.25697.3: 100%|##########| 11.8k/11.8k [00:00<?, ?…
# To https://huggingface.co/SeoJeongYun/bert-base-banking77-pt2-jy
#    f9da4a5..f7540b3  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/SeoJeongYun/bert-base-banking77-pt2-jy
#    f9da4a5..f7540b3  main -> main
# 'https://huggingface.co/SeoJeongYun/bert-base-banking77-pt2-jy/commit/f7540b3b0ef69a297508cae5f16d3b64e3bad869'

# %%
### Test

from transformers import pipeline

if __name__ == '__main__':
    trainer = engine()
    # load model from huggingface.co/models using our repository id
    classifier = pipeline("sentiment-analysis", model=trainer.repo_id, tokenizer=trainer.repo_id, device=0)

    sample = "I have been waiting longer than expected for my bank card, could you provide information on when it will arrive?"

    pred = classifier(sample)
    print(pred)
    # [{'label': 'card_arrival', 'score': 0.9903606176376343}]
# Out:
# /root/.cache/huggingface/modules/datasets_modules/datasets/banking77/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4/banking77.py:59: FutureWarning: Dataset 'banking77' is deprecated and will be deleted. Use 'PolyAI/banking77' instead.
#   warnings.warn(
# WARNING:datasets.builder:Found cached dataset banking77 (/root/.cache/huggingface/datasets/banking77/default/1.1.0/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4)
#   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/banking77/default/1.1.0/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4/cache-7ddd421b53cb0109.arrow
# WARNING:datasets.builder:Found cached dataset banking77 (/root/.cache/huggingface/datasets/banking77/default/1.1.0/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4)
#   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/banking77/default/1.1.0/9898c11f6afa9521953d2ef205667b527bad14ef9cab445d470f16240c8c8ec4/cache-c3b98d4721feba05.arrow
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The speedups for torchdynamo mostly come wih GPU Ampere or higher and which is not detected here.
# /content/bert-base-banking77-pt2-jy is already a clone of https://huggingface.co/SeoJeongYun/bert-base-banking77-pt2-jy. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/bert-base-banking77-pt2-jy is already a clone of https://huggingface.co/SeoJeongYun/bert-base-banking77-pt2-jy. Make sure you pull the latest changes with `repo.git_pull()`.
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# [{'label': 'card_arrival', 'score': 0.6612871885299683}]
